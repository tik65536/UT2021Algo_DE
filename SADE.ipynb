# %%
import torch
import numpy as np
import pickle
#from torchsummary import summary
from collections import OrderedDict
from torch.utils.tensorboard import SummaryWriter
import datetime
import time
import copy
import torchvision.datasets as datasets
mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=None)
mnist_testset = datasets.MNIST(root='./data', train=False, download=True, transform=None)

# %%
class DNN(torch.nn.Module):
    def __init__(self, layers):
        super(DNN, self).__init__()
        
        # parameters
        self.depth = len(layers)-1
        self.activation = torch.nn.ReLU
        
        layer_list = list()
        for i in range(self.depth-1): 
            layer_list.append(
                ('layer_%d' % i, torch.nn.Linear(layers[i], layers[i+1]))
            )
            layer_list.append(('activation_%d' % i, self.activation()))
            
        layer_list.append(
            ('layer_%d' % (self.depth - 1), torch.nn.Linear(layers[-2], layers[-1]))
        )
        
        layerDict = OrderedDict(layer_list)
        
        # deploy layers
        self.layers = torch.nn.Sequential(layerDict)
        
    def forward(self, x):
        out = self.layers(x)
        return out

# %%
class DE_MLP():
    def __init__(self, outdim=1,maxdepth=70,mindepth=5,minneuron=4,maxneuron=10,bsize=10,epoch=100,initSize=20,maxiter=10,stopcount=3,\
                 trainingset=None,validationset=None,trainingTarget=None,validateTarget=None,crossover=1):
        self.best=[]
        self.mean=[]
        self.outdim=outdim
        self.maxdepth=maxdepth
        self.mindepth=mindepth
        self.minneuron = minneuron
        self.maxneuron = maxneuron
        self.bsize = bsize
        self.epoch = epoch
        self.stopcount = stopcount
        self.pplSize = initSize
        self.maxiter = maxiter
        self.training = trainingset.reshape((trainingset.shape[0],-1))
        self.validationSet = validationset.reshape((validationset.shape[0],-1))
        self.target=trainingTarget
        self.validationTarget = validateTarget
        self.MLPlayerlist = []
        self.depthlist=np.random.choice(range(self.mindepth,self.maxdepth),self.pplSize,replace=True)
        self.crossover=crossover
        self.tb = SummaryWriter('./Statistic/'+datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
        self.device = torch.device('cpu')

        for i in range(self.pplSize):
            depth = self.depthlist[i]
            tmp=[]
            tmp.append(self.training.shape[1])
            for j in range(depth):
                tmp.append(np.random.choice(range(self.minneuron,self.maxneuron),1,replace=False)[0])
            tmp.append(self.outdim)
            tmp=np.array(tmp)
            self.MLPlayerlist.append(tmp)

    def fit(self,config,id_,p=None):
        dnn = DNN(config)
        dnn.layers.to(self.device)
        best = float('inf')
        stop=0
        opt = torch.optim.Adam(dnn.layers.parameters(), lr=0.001)
        loss = torch.nn.BCEWithLogitsLoss()
        batch = self.training.shape[0]//self.bsize
        vbatch = self.validationSet.shape[0]//self.bsize
        idxs = [x for x in range(self.training.shape[0])]
        vidxs = [x for x in range(self.validationSet.shape[0])]
        for e in range(self.epoch):
            start=time.time()
            np.random.shuffle(idxs)
            dnn.layers.train()
            batchloss=0
            for i in range(batch):
                idx=idxs[i*self.bsize:i*self.bsize+self.bsize]
                opt.zero_grad()
                data = torch.tensor(self.training[idx]).float().to(self.device)
                y = torch.tensor(self.target[idx]).float().to(self.device)
                yhat = dnn(data)
                l = loss(yhat,y)
                batchloss+=l.item()
                l.backward()
                opt.step()

            dnn.layers.eval()
            np.random.shuffle(vidxs)
            vloss=0
            for i in range(vbatch):
                vidx=vidxs[i*self.bsize:i*self.bsize+self.bsize]
                vdata = torch.tensor(self.validationSet[vidx]).float().to(self.device)
                vy = torch.tensor(self.validationTarget[vidx]).float().to(self.device)
                vyhat = dnn(vdata)
                vl = loss(vyhat,vy)
                vloss += vl.item()
            vloss = vloss/vbatch
            if(vloss<best):
                best=vloss
            else:
                stop+=1
            end=time.time()
            if(p is not None):
                print(f'Process: {p:3d}, ConfigID: {id_:3d}, Epoch: {e:3d}, Training Loss: {(batchloss/batch):10.8f}, Validation Loss: {(vloss):10.8f},\
                    Best: {best:10.8f}, StopCount/Limit: {stop:3d}/{self.stopcount:3d}, Time:{(end-start):10.8f}')
            else:
                print(f'ConfigID: {id_:3d}, Epoch: {e:3d}, Training Loss: {(batchloss/batch):10.8f}, Validation Loss: {(vloss):10.8f},\
                    Best: {best:10.8f}, StopCount/Limit: {stop:3d}/{self.stopcount:3d}, Time:{(end-start):10.8f}')
            if(stop>=self.stopcount):
                return best,config,id_
    
    def mutation_rand_1_z(self,x1,xs,beta,debug=False):
        indim = x1[0]
        x1 = x1[1:-1] # remove in/out dim
        xs[0] = xs[0][1:-1]
        xs[1] = xs[1][1:-1]
        if(debug):
            print(f'M1 : x1 len {x1.shape[0]} xs0 len {xs[0].shape[0]} xs1 len {xs[1].shape[0]}')
            print(f'M1 : x1 {x1} \nM1 : xs0 {xs[0]} \nM1 : xs1 len {xs[1]}')
        #
        # A. Mutating the # of layers
        minlen = np.min([x1.shape[0],xs[0].shape[0],xs[1].shape[0]])
        if(debug): print(f'M1 : minlen {minlen}')
        newminlen = minlen
        targetlen=int(np.floor((x1.shape[0]) + beta * (xs[0].shape[0] - xs[1].shape[0])))
        if(targetlen==0): targetlen=x1.shape[0]
        elif(targetlen<0): targetlen=abs(targetlen)
        if(targetlen<self.mindepth): targetlen=self.mindepth
        if(targetlen>self.maxdepth): targetlen=self.maxdepth
        if(targetlen < minlen): newminlen=targetlen
        if(debug): print(f'M1 : New Min Len :{newminlen}, Length Mutation :{targetlen}')
        #    
        # B. Mutating the # of neurons
        # As lengths of x1, xs[0], xs[1] and new length can possibly be different, 
        # 1) do the mutation for # of neurons for new minlen, 
        # 2) apply the same rule to remaining if needed
        xa = x1[:newminlen] + beta * (xs[0][:newminlen] - xs[1][:newminlen])
        if(targetlen>minlen):
            xaa = np.zeros((targetlen-minlen))
            a,b,c=None,None,None
            for i in range(targetlen-newminlen):
                if(x1.shape[0]<=newminlen+i): a=np.random.choice(range(self.minneuron,self.maxneuron),1,replace=False)[0]
                elif(x1.shape[0]>newminlen+i): a=x1[newminlen+i]
                if(xs[0].shape[0]<=newminlen+i): b=np.random.choice(range(self.minneuron,self.maxneuron),1,replace=False)[0]
                elif(xs[0].shape[0]>newminlen+i): b=xs[0][newminlen+i]
                if(xs[1].shape[0]<=newminlen+i): c=np.random.choice(range(self.minneuron,self.maxneuron),1,replace=False)[0]
                elif(xs[1].shape[0]>newminlen+i): c=xs[1][newminlen+i]
                xaa[i]=a + beta * (b - c)
            xa = np.concatenate((xa, xaa), axis=None)
        for i in range(xa.shape[0]):
            if(xa[i]>self.maxneuron): xa[i]=self.maxneuron
            elif(xa[i]<self.minneuron): xa[i]=self.minneuron
            xa[i] = np.floor(xa[i])
        xa = np.concatenate((np.array(indim,dtype=int),np.array(xa,dtype=int),np.array(self.outdim,dtype=int)), axis=None,dtype=int)
        return xa
    
    def mutation_current2best_2_z(self,x,xp,xs,beta,debug=False):
        indim = x[0]
        x = x[1:-1]
        xp = xp[1:-1]
        xs[0] = xs[0][1:-1]
        xs[1] = xs[1][1:-1]
        if(debug):
            print(f'M1 : x len {x.shape[0]} xp len {xp.shape[0]} xs0 len {xs[0].shape[0]} xs1 len {xs[1].shape[0]}')
            print(f'M1 : x {x} \nM1 : xp {xp} \nM1 : xs0 {xs[0]} \nM1 : xs1 len {xs[1]}')
        #
        # A. Mutating the # of layers
        minlen = np.min([x.shape[0],xp.shape[0],xs[0].shape[0],xs[1].shape[0]])
        if(debug): print(f'M1 : minlen {minlen}')
        newminlen = minlen
        targetlen=int(np.floor( (x.shape[0]) + beta * (xp.shape[0] - x.shape[0]) + beta * (xs[0].shape[0] - xs[1].shape[0]) ))
        if(targetlen==0): targetlen=xp.shape[0]
        elif(targetlen<0): targetlen=abs(targetlen)
        if(targetlen<self.mindepth): targetlen=self.mindepth
        if(targetlen>self.maxdepth): targetlen=self.maxdepth
        if(targetlen < minlen): newminlen=targetlen
        if(debug): print(f'M1 : New Min Len :{newminlen}, Length Mutation :{targetlen}')
        #    
        # B. Mutating the # of neurons
        # As lengths of x, xp, xs[0], xs[1] and new length can possibly be different, 
        # 1) do the mutation for # of neurons for new minlen, 
        # 2) apply the same rule to remaining if needed
        xa = x[:newminlen] + beta * (xp[:newminlen] - x[:newminlen]) + beta * (xs[0][:newminlen] - xs[1][:newminlen])
        if(targetlen>minlen):
            xaa = np.zeros((targetlen-minlen))
            a,b,c,d=None,None,None,None
            for i in range(targetlen-newminlen):
                if(x.shape[0]<=newminlen+i): a=np.random.choice(range(self.minneuron,self.maxneuron),1,replace=False)[0]
                elif(x.shape[0]>newminlen+i): a=x[newminlen+i]
                if(xp.shape[0]<=newminlen+i): b=np.random.choice(range(self.minneuron,self.maxneuron),1,replace=False)[0]
                elif(xp.shape[0]>newminlen+i): b=xp[newminlen+i]
                if(xs[0].shape[0]<=newminlen+i): c=np.random.choice(range(self.minneuron,self.maxneuron),1,replace=False)[0]
                elif(xs[0].shape[0]>newminlen+i): c=xs[0][newminlen+i]
                if(xs[1].shape[0]<=newminlen+i): d=np.random.choice(range(self.minneuron,self.maxneuron),1,replace=False)[0]
                elif(xs[1].shape[0]>newminlen+i): d=xs[1][newminlen+i]
                xaa[i]=a + beta * (b - a) + beta * (c - d)
            xa = np.concatenate((xa, xaa), axis=None)
        for i in range(xa.shape[0]):
            if(xa[i]>self.maxneuron): xa[i]=self.maxneuron
            elif(xa[i]<self.minneuron): xa[i]=self.minneuron
            xa[i] = np.floor(xa[i])
        xa = np.concatenate((np.array(indim,dtype=int),np.array(xa,dtype=int),np.array(self.outdim,dtype=int)), axis=None,dtype=int)
        return xa
    
    def crossoverUnif(self,parent,u,cr):
        r = np.random.uniform(0,1,1)[0]
        order = [parent[1:-1],u[1:-1]]
        child = [parent[0]]
        if(parent.shape[0] > u.shape[0]):
            order = [u[1:-1],parent[1:-1]]
        order[0] = np.resize(order[0],order[1].shape[0])
        jr = np.random.choice(range(order[0].shape[0]),size=1)[0]
        for j in range(order[0].shape[0]):
            if r <= cr or j == jr: child.append(order[0][j])
            else: child.append(order[1][j])
        child.append(parent[-1])
        return np.array(child)

    def run(self):
        current_gen=self.MLPlayerlist
        scores = np.zeros((self.pplSize))
        #initial Run
        print('Initial Run Start')
        for i in range(len(current_gen)):
            b,_,_ = self.fit(current_gen[i],i)
            scores[i]=b
        print('Initial Run End')
        currentbest = np.min(scores)
        currentmean = np.mean(scores)
        currentbestidx = np.argmin(scores)
        print(f'Init Run Best: {currentbest}, Mean: {currentmean}, ID:{currentbestidx}, config: {current_gen[currentbestidx]}')
        # initial factors
        p1,beta,crm = 0.5,0,0.5
        crs = []
        progress = []
        #Generation Run
        for i in range(self.maxiter):
            structureStatistic=np.zeros((self.pplSize,5))
            updatecount=0
            start=time.time()
            ns1,nf1,ns2,nf2 = 0,0,0,0
            print(f'Gen {i} Run Start')
            for j in range(self.pplSize):
                parent = current_gen[j]
                # factors
                while beta <= 0 or beta > 2: beta = np.random.normal(loc=0.5,scale=0.3,size=1)[0]
                if i%5==0: cr = np.random.normal(loc=crm,scale=0.1,size=1)[0]
                r = np.random.uniform(low=0,high=1,size=1)[0]
                # strategy selection + mutation
                if r <= p1: 
                    idx0,idx1,idxt = np.random.choice(range(0,self.pplSize),3,replace=False)
                    target = current_gen[idxt]
                    diff = [current_gen[idx0],current_gen[idx1]]
                    unitvector = self.mutation_rand_1_z(target,diff,beta)
                else:
                    idxt = np.argmax(scores)
                    idx0,idx1 = np.random.choice(np.delete(np.arange(self.pplSize),idxt),2,replace=False)
                    target = current_gen[idxt]
                    diff = [current_gen[idx0],current_gen[idx1]]
                    unitvector = self.mutation_current2best_2_z(parent,target,diff,beta)
                # crossover
                child = self.crossoverUnif(parent,unitvector,cr)
                print(f'Next Gen: {child}')
                structureStatistic[j,0]= child.shape[0]
                structureStatistic[j,1]= np.mean(child)
                structureStatistic[j,2]= np.median(child)
                structureStatistic[j,3]= np.quantile(child,0.25)
                structureStatistic[j,4]= np.quantile(child,0.75)
                # selection
                s,_,_ = self.fit(child,j)
                if(s < scores[j]):
                    updatecount+=1
                    scores[j]=s
                    current_gen[j]=child
                    crs.append(cr)
                    if r <= p1: ns1 += 1
                    else: ns2 += 1
                else:
                    if r <= p1: nf1 += 1
                    else: nf2 += 1
            if i%5==4: 
                crm = np.mean(crs)
                crs = []
            if(ns2*(ns1+nf1)+ns1*(ns2+nf2) == 0): p1 = 0
            else: p1 = (ns1*(ns2+nf2))/(ns2*(ns1+nf1)+ns1*(ns2+nf2))
            print(f'Gen {i} Run End')
            end=time.time()
            currentbest = np.min(scores)
            currentmean = np.mean(scores)
            currentmedian = np.median(scores)
            currentq25 = np.quantile(scores,0.25)
            currentq75 = np.quantile(scores,0.75)
            currentbestidx = np.argmin(scores)
            genMeanLen = np.mean(structureStatistic[:,0])
            genMedianLen = np.median(structureStatistic[:,0])
            genq25Len = np.quantile(structureStatistic[:,0],0.25)
            genq75Len = np.quantile(structureStatistic[:,0],0.75)
            genMeanNode=np.median(structureStatistic[:,1])
            genMedianNode=np.median(structureStatistic[:,2])
            genq25Node = np.median(structureStatistic[:,3])
            genq75Node = np.median(structureStatistic[:,4])
            print(f'Run {i:3d} Best: {currentbest}, Mean: {currentmean}, ID:{currentbestidx}, config: {current_gen[currentbestidx]}, updatecount: {updatecount:3d}, Generation RunTime: {(end-start):10.8f}')
            self.tb.add_scalars("Scores Statistic (Generation)", {'best':currentbest,'mean':currentmean,'median':currentmedian,'q25':currentq25,'q75':currentq75}, i)
            self.tb.add_scalars("Structure Statistic (Generation) #HiddenLayer", {'mean':genMeanLen,'median':genMedianLen,'q25':genq25Len,'q75':genq75Len}, i)
            self.tb.add_scalars("Structure Statistic (Generation) #Node", {'mean':genMeanNode,'median':genMedianNode,'q25':genq25Node,'q75':genq75Node}, i)
            self.tb.add_scalar('Update Count',updatecount,i)
            self.tb.add_scalar('RunTime',(end-start),i)
            
        print(f'Run Completed : Best Score(loss): {np.min(scores)} , Config: {current_gen[np.argmin(scores)]}')
        return

# %%
trainingt = torch.nn.functional.one_hot(mnist_trainset.targets,num_classes=10)
validationt = torch.nn.functional.one_hot(mnist_testset.targets,num_classes=10)
# (self, outdim=1,maxdepth=70,mindepth=5,minneuron=4,maxneuron=10,bsize=10,epoch=100,initSize=20,maxiter=10,stopcount=3,
#   trainingset=None,validationset=None,trainingTarget=None,validateTarget=None)
d = DE_MLP(outdim=10,maxdepth=10,initSize=3,trainingset=mnist_trainset.data, validationset=mnist_testset.data, trainingTarget=trainingt,validateTarget=validationt)

# %%
d.run()
# Out:
# Initial Run Start
# /var/folders/hk/kbn1q_sj4jz4lh0m7x05vff80000gn/T/ipykernel_8683/2980509036.py:55: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data = torch.tensor(self.training[idx]).float().to(self.device)
# /var/folders/hk/kbn1q_sj4jz4lh0m7x05vff80000gn/T/ipykernel_8683/2980509036.py:56: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(self.target[idx]).float().to(self.device)
# /var/folders/hk/kbn1q_sj4jz4lh0m7x05vff80000gn/T/ipykernel_8683/2980509036.py:68: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   vdata = torch.tensor(self.validationSet[vidx]).float().to(self.device)
# /var/folders/hk/kbn1q_sj4jz4lh0m7x05vff80000gn/T/ipykernel_8683/2980509036.py:69: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   vy = torch.tensor(self.validationTarget[vidx]).float().to(self.device)
# ConfigID:   0, Epoch:   0, Training Loss: 0.25343836, Validation Loss: 0.17032708,                    Best: 0.17032708, StopCount/Limit:   0/  3, Time:18.34860015
# ConfigID:   0, Epoch:   1, Training Loss: 0.16133059, Validation Loss: 0.15610030,                    Best: 0.15610030, StopCount/Limit:   0/  3, Time:12.64001489
# ConfigID:   0, Epoch:   2, Training Loss: 0.15080434, Validation Loss: 0.14804331,                    Best: 0.14804331, StopCount/Limit:   0/  3, Time:12.84339714
# ConfigID:   0, Epoch:   3, Training Loss: 0.14607684, Validation Loss: 0.14186661,                    Best: 0.14186661, StopCount/Limit:   0/  3, Time:13.17812300
# ConfigID:   0, Epoch:   4, Training Loss: 0.14185399, Validation Loss: 0.13800694,                    Best: 0.13800694, StopCount/Limit:   0/  3, Time:23.11757207
# ConfigID:   0, Epoch:   5, Training Loss: 0.13793102, Validation Loss: 0.14900279,                    Best: 0.13800694, StopCount/Limit:   1/  3, Time:30.43228388
# ConfigID:   0, Epoch:   6, Training Loss: 0.13526788, Validation Loss: 0.13604879,                    Best: 0.13604879, StopCount/Limit:   1/  3, Time:23.25082898
# ConfigID:   0, Epoch:   7, Training Loss: 0.12909359, Validation Loss: 0.12761454,                    Best: 0.12761454, StopCount/Limit:   1/  3, Time:25.71667695
# ConfigID:   0, Epoch:   8, Training Loss: 0.12689908, Validation Loss: 0.12308498,                    Best: 0.12308498, StopCount/Limit:   1/  3, Time:16.70011115
# ConfigID:   0, Epoch:   9, Training Loss: 0.12377045, Validation Loss: 0.12143014,                    Best: 0.12143014, StopCount/Limit:   1/  3, Time:15.85918593
# ConfigID:   0, Epoch:  10, Training Loss: 0.12086304, Validation Loss: 0.11814248,                    Best: 0.11814248, StopCount/Limit:   1/  3, Time:15.82495093
# ConfigID:   0, Epoch:  11, Training Loss: 0.11966694, Validation Loss: 0.11794406,                    Best: 0.11794406, StopCount/Limit:   1/  3, Time:18.75111699
# ConfigID:   0, Epoch:  12, Training Loss: 0.11708870, Validation Loss: 0.11335710,                    Best: 0.11335710, StopCount/Limit:   1/  3, Time:25.14708686
# ConfigID:   0, Epoch:  13, Training Loss: 0.11558521, Validation Loss: 0.11428031,                    Best: 0.11335710, StopCount/Limit:   2/  3, Time:22.98670602
# ConfigID:   0, Epoch:  14, Training Loss: 0.11536541, Validation Loss: 0.12727776,                    Best: 0.11335710, StopCount/Limit:   3/  3, Time:20.35824990
# ConfigID:   1, Epoch:   0, Training Loss: 0.24295473, Validation Loss: 0.17637859,                    Best: 0.17637859, StopCount/Limit:   0/  3, Time:17.37605309
# ConfigID:   1, Epoch:   1, Training Loss: 0.15799107, Validation Loss: 0.14369824,                    Best: 0.14369824, StopCount/Limit:   0/  3, Time:15.55511713
# ConfigID:   1, Epoch:   2, Training Loss: 0.13950383, Validation Loss: 0.13511878,                    Best: 0.13511878, StopCount/Limit:   0/  3, Time:13.87053394
# ConfigID:   1, Epoch:   3, Training Loss: 0.13264516, Validation Loss: 0.13001425,                    Best: 0.13001425, StopCount/Limit:   0/  3, Time:13.36441493
# ConfigID:   1, Epoch:   4, Training Loss: 0.12441063, Validation Loss: 0.11927457,                    Best: 0.11927457, StopCount/Limit:   0/  3, Time:14.62263894
# ConfigID:   1, Epoch:   5, Training Loss: 0.11729945, Validation Loss: 0.11596556,                    Best: 0.11596556, StopCount/Limit:   0/  3, Time:15.32369089
# ConfigID:   1, Epoch:   6, Training Loss: 0.11349277, Validation Loss: 0.11168078,                    Best: 0.11168078, StopCount/Limit:   0/  3, Time:13.58397508
# ConfigID:   1, Epoch:   7, Training Loss: 0.10911350, Validation Loss: 0.11235470,                    Best: 0.11168078, StopCount/Limit:   1/  3, Time:15.25070786
# ConfigID:   1, Epoch:   8, Training Loss: 0.10644753, Validation Loss: 0.10945549,                    Best: 0.10945549, StopCount/Limit:   1/  3, Time:12.86274600
# ConfigID:   1, Epoch:   9, Training Loss: 0.10470993, Validation Loss: 0.10704346,                    Best: 0.10704346, StopCount/Limit:   1/  3, Time:13.55857205
# ConfigID:   1, Epoch:  10, Training Loss: 0.10391493, Validation Loss: 0.10335713,                    Best: 0.10335713, StopCount/Limit:   1/  3, Time:13.07100487
# ConfigID:   1, Epoch:  11, Training Loss: 0.10273756, Validation Loss: 0.10307476,                    Best: 0.10307476, StopCount/Limit:   1/  3, Time:15.27233315
# ConfigID:   1, Epoch:  12, Training Loss: 0.10219010, Validation Loss: 0.10332291,                    Best: 0.10307476, StopCount/Limit:   2/  3, Time:12.68249011
# ConfigID:   1, Epoch:  13, Training Loss: 0.09987595, Validation Loss: 0.10256056,                    Best: 0.10256056, StopCount/Limit:   2/  3, Time:12.80721211
# ConfigID:   1, Epoch:  14, Training Loss: 0.10097129, Validation Loss: 0.09637918,                    Best: 0.09637918, StopCount/Limit:   2/  3, Time:12.62838578
# ConfigID:   1, Epoch:  15, Training Loss: 0.09863836, Validation Loss: 0.09991129,                    Best: 0.09637918, StopCount/Limit:   3/  3, Time:12.49001598
# ConfigID:   2, Epoch:   0, Training Loss: 0.31873394, Validation Loss: 0.27026190,                    Best: 0.27026190, StopCount/Limit:   0/  3, Time:12.50661302
# ConfigID:   2, Epoch:   1, Training Loss: 0.26323163, Validation Loss: 0.26643693,                    Best: 0.26643693, StopCount/Limit:   0/  3, Time:12.87873983
# ConfigID:   2, Epoch:   2, Training Loss: 0.26091261, Validation Loss: 0.26468290,                    Best: 0.26468290, StopCount/Limit:   0/  3, Time:12.56175685
# ConfigID:   2, Epoch:   3, Training Loss: 0.26011374, Validation Loss: 0.26560497,                    Best: 0.26468290, StopCount/Limit:   1/  3, Time:12.81453013
# ConfigID:   2, Epoch:   4, Training Loss: 0.25892902, Validation Loss: 0.27226534,                    Best: 0.26468290, StopCount/Limit:   2/  3, Time:12.71318579
# ConfigID:   2, Epoch:   5, Training Loss: 0.25892016, Validation Loss: 0.26765357,                    Best: 0.26468290, StopCount/Limit:   3/  3, Time:14.60099292
# Initial Run End
# Init Run Best: 0.09637917943112552, Mean: 0.1581397246743242, ID:1, config: [784   4   5   9   6   6   5   9   8   6  10]
# Gen 0 Run Start
# Next Gen: [784   4   4   8   4   4   8   7   6   6  10]
# ConfigID:   0, Epoch:   0, Training Loss: 0.27600981, Validation Loss: 0.23108254,                    Best: 0.23108254, StopCount/Limit:   0/  3, Time:12.48892093
# ConfigID:   0, Epoch:   1, Training Loss: 0.22574088, Validation Loss: 0.21991430,                    Best: 0.21991430, StopCount/Limit:   0/  3, Time:12.43699384
# ConfigID:   0, Epoch:   2, Training Loss: 0.21791712, Validation Loss: 0.21593139,                    Best: 0.21593139, StopCount/Limit:   0/  3, Time:13.23950696
# ConfigID:   0, Epoch:   3, Training Loss: 0.21083060, Validation Loss: 0.20970997,                    Best: 0.20970997, StopCount/Limit:   0/  3, Time:13.21553421
# ConfigID:   0, Epoch:   4, Training Loss: 0.20637385, Validation Loss: 0.20705266,                    Best: 0.20705266, StopCount/Limit:   0/  3, Time:10.66136193
# ConfigID:   0, Epoch:   5, Training Loss: 0.20415562, Validation Loss: 0.20500995,                    Best: 0.20500995, StopCount/Limit:   0/  3, Time:10.52909112
# ConfigID:   0, Epoch:   6, Training Loss: 0.20216209, Validation Loss: 0.20111236,                    Best: 0.20111236, StopCount/Limit:   0/  3, Time:9.95472574
# ConfigID:   0, Epoch:   7, Training Loss: 0.20147730, Validation Loss: 0.20830099,                    Best: 0.20111236, StopCount/Limit:   1/  3, Time:11.69843984
# ConfigID:   0, Epoch:   8, Training Loss: 0.20003382, Validation Loss: 0.19692891,                    Best: 0.19692891, StopCount/Limit:   1/  3, Time:11.82263708
# ConfigID:   0, Epoch:   9, Training Loss: 0.19785986, Validation Loss: 0.20427232,                    Best: 0.19692891, StopCount/Limit:   2/  3, Time:9.78207302
# ConfigID:   0, Epoch:  10, Training Loss: 0.19674942, Validation Loss: 0.19527610,                    Best: 0.19527610, StopCount/Limit:   2/  3, Time:11.07324219
# ConfigID:   0, Epoch:  11, Training Loss: 0.19743620, Validation Loss: 0.19445938,                    Best: 0.19445938, StopCount/Limit:   2/  3, Time:10.99910092
# ConfigID:   0, Epoch:  12, Training Loss: 0.19591435, Validation Loss: 0.19560707,                    Best: 0.19445938, StopCount/Limit:   3/  3, Time:10.18924284
# Next Gen: [784   9   5   4   8   6   7   4   4   9  10]
# ConfigID:   1, Epoch:   0, Training Loss: 0.30065038, Validation Loss: 0.26159151,                    Best: 0.26159151, StopCount/Limit:   0/  3, Time:11.44281602
# ConfigID:   1, Epoch:   1, Training Loss: 0.25687615, Validation Loss: 0.25202266,                    Best: 0.25202266, StopCount/Limit:   0/  3, Time:9.46278715
# ConfigID:   1, Epoch:   2, Training Loss: 0.25298552, Validation Loss: 0.25125711,                    Best: 0.25125711, StopCount/Limit:   0/  3, Time:9.47564220
# ConfigID:   1, Epoch:   3, Training Loss: 0.25097855, Validation Loss: 0.25012985,                    Best: 0.25012985, StopCount/Limit:   0/  3, Time:9.40328288
# ConfigID:   1, Epoch:   4, Training Loss: 0.24952756, Validation Loss: 0.24923302,                    Best: 0.24923302, StopCount/Limit:   0/  3, Time:9.21836400
# ConfigID:   1, Epoch:   5, Training Loss: 0.24834984, Validation Loss: 0.24858701,                    Best: 0.24858701, StopCount/Limit:   0/  3, Time:9.35428905
# ConfigID:   1, Epoch:   6, Training Loss: 0.24434830, Validation Loss: 0.23506406,                    Best: 0.23506406, StopCount/Limit:   0/  3, Time:9.30398273
# ConfigID:   1, Epoch:   7, Training Loss: 0.22118472, Validation Loss: 0.20749843,                    Best: 0.20749843, StopCount/Limit:   0/  3, Time:9.31984997
# ConfigID:   1, Epoch:   8, Training Loss: 0.19689633, Validation Loss: 0.18847310,                    Best: 0.18847310, StopCount/Limit:   0/  3, Time:9.27809691
# ConfigID:   1, Epoch:   9, Training Loss: 0.18325118, Validation Loss: 0.17785112,                    Best: 0.17785112, StopCount/Limit:   0/  3, Time:9.30920076
# ConfigID:   1, Epoch:  10, Training Loss: 0.17372075, Validation Loss: 0.16677655,                    Best: 0.16677655, StopCount/Limit:   0/  3, Time:9.59929991
# ConfigID:   1, Epoch:  11, Training Loss: 0.16705848, Validation Loss: 0.16183017,                    Best: 0.16183017, StopCount/Limit:   0/  3, Time:9.31043696
# ConfigID:   1, Epoch:  12, Training Loss: 0.16223246, Validation Loss: 0.15545475,                    Best: 0.15545475, StopCount/Limit:   0/  3, Time:9.42371702
# ConfigID:   1, Epoch:  13, Training Loss: 0.15740884, Validation Loss: 0.15522604,                    Best: 0.15522604, StopCount/Limit:   0/  3, Time:9.36814117
# ConfigID:   1, Epoch:  14, Training Loss: 0.15201961, Validation Loss: 0.15695576,                    Best: 0.15522604, StopCount/Limit:   1/  3, Time:9.38553619
# ConfigID:   1, Epoch:  15, Training Loss: 0.14865237, Validation Loss: 0.15326916,                    Best: 0.15326916, StopCount/Limit:   1/  3, Time:9.42779803
# ConfigID:   1, Epoch:  16, Training Loss: 0.14573079, Validation Loss: 0.14581735,                    Best: 0.14581735, StopCount/Limit:   1/  3, Time:9.38244605
# ConfigID:   1, Epoch:  17, Training Loss: 0.14161689, Validation Loss: 0.13732649,                    Best: 0.13732649, StopCount/Limit:   1/  3, Time:9.43181109
# ConfigID:   1, Epoch:  18, Training Loss: 0.13882958, Validation Loss: 0.13610657,                    Best: 0.13610657, StopCount/Limit:   1/  3, Time:9.37542200
# ConfigID:   1, Epoch:  19, Training Loss: 0.13530508, Validation Loss: 0.13512220,                    Best: 0.13512220, StopCount/Limit:   1/  3, Time:9.27792096
# ConfigID:   1, Epoch:  20, Training Loss: 0.13381560, Validation Loss: 0.12827481,                    Best: 0.12827481, StopCount/Limit:   1/  3, Time:9.34908819
# ConfigID:   1, Epoch:  21, Training Loss: 0.13122565, Validation Loss: 0.12422544,                    Best: 0.12422544, StopCount/Limit:   1/  3, Time:9.29962540
# ConfigID:   1, Epoch:  22, Training Loss: 0.12582965, Validation Loss: 0.12196807,                    Best: 0.12196807, StopCount/Limit:   1/  3, Time:9.23965693
# ConfigID:   1, Epoch:  23, Training Loss: 0.12493707, Validation Loss: 0.11965688,                    Best: 0.11965688, StopCount/Limit:   1/  3, Time:9.35910201
# ConfigID:   1, Epoch:  24, Training Loss: 0.11775948, Validation Loss: 0.11384817,                    Best: 0.11384817, StopCount/Limit:   1/  3, Time:9.30400515
# ConfigID:   1, Epoch:  25, Training Loss: 0.11472070, Validation Loss: 0.10956902,                    Best: 0.10956902, StopCount/Limit:   1/  3, Time:9.22882700
# ConfigID:   1, Epoch:  26, Training Loss: 0.11124406, Validation Loss: 0.10692505,                    Best: 0.10692505, StopCount/Limit:   1/  3, Time:9.35932612
# ConfigID:   1, Epoch:  27, Training Loss: 0.10739614, Validation Loss: 0.10514107,                    Best: 0.10514107, StopCount/Limit:   1/  3, Time:9.36368895
# ConfigID:   1, Epoch:  28, Training Loss: 0.10454532, Validation Loss: 0.10453156,                    Best: 0.10453156, StopCount/Limit:   1/  3, Time:9.34445286
# ConfigID:   1, Epoch:  29, Training Loss: 0.10386786, Validation Loss: 0.10076360,                    Best: 0.10076360, StopCount/Limit:   1/  3, Time:9.30804801
# ConfigID:   1, Epoch:  30, Training Loss: 0.10001466, Validation Loss: 0.10143483,                    Best: 0.10076360, StopCount/Limit:   2/  3, Time:9.30188680
# ConfigID:   1, Epoch:  31, Training Loss: 0.09794465, Validation Loss: 0.09707780,                    Best: 0.09707780, StopCount/Limit:   2/  3, Time:10.02632403
# ConfigID:   1, Epoch:  32, Training Loss: 0.09676201, Validation Loss: 0.09516996,                    Best: 0.09516996, StopCount/Limit:   2/  3, Time:9.75397396
# ConfigID:   1, Epoch:  33, Training Loss: 0.09684803, Validation Loss: 0.09218382,                    Best: 0.09218382, StopCount/Limit:   2/  3, Time:9.64503098
# ConfigID:   1, Epoch:  34, Training Loss: 0.09495918, Validation Loss: 0.08927468,                    Best: 0.08927468, StopCount/Limit:   2/  3, Time:9.40904784
# ConfigID:   1, Epoch:  35, Training Loss: 0.09144762, Validation Loss: 0.09274519,                    Best: 0.08927468, StopCount/Limit:   3/  3, Time:9.30944490
# Next Gen: [784   7   4   5   6   5   9   5   5   6  10]
# ConfigID:   2, Epoch:   0, Training Loss: 0.29171409, Validation Loss: 0.23506499,                    Best: 0.23506499, StopCount/Limit:   0/  3, Time:9.16468501
# ConfigID:   2, Epoch:   1, Training Loss: 0.22757024, Validation Loss: 0.22197277,                    Best: 0.22197277, StopCount/Limit:   0/  3, Time:9.17733192
# ConfigID:   2, Epoch:   2, Training Loss: 0.21353444, Validation Loss: 0.20615134,                    Best: 0.20615134, StopCount/Limit:   0/  3, Time:9.18770099
# ConfigID:   2, Epoch:   3, Training Loss: 0.20479799, Validation Loss: 0.19771747,                    Best: 0.19771747, StopCount/Limit:   0/  3, Time:9.17240596
# ConfigID:   2, Epoch:   4, Training Loss: 0.19878542, Validation Loss: 0.19375652,                    Best: 0.19375652, StopCount/Limit:   0/  3, Time:9.11573792
# ConfigID:   2, Epoch:   5, Training Loss: 0.19328723, Validation Loss: 0.18914036,                    Best: 0.18914036, StopCount/Limit:   0/  3, Time:9.20532489
# ConfigID:   2, Epoch:   6, Training Loss: 0.18927955, Validation Loss: 0.18588545,                    Best: 0.18588545, StopCount/Limit:   0/  3, Time:9.10041976
# ConfigID:   2, Epoch:   7, Training Loss: 0.18623807, Validation Loss: 0.18528144,                    Best: 0.18528144, StopCount/Limit:   0/  3, Time:9.09742999
# ConfigID:   2, Epoch:   8, Training Loss: 0.18397482, Validation Loss: 0.18661332,                    Best: 0.18528144, StopCount/Limit:   1/  3, Time:9.20098782
# ConfigID:   2, Epoch:   9, Training Loss: 0.18166673, Validation Loss: 0.18404191,                    Best: 0.18404191, StopCount/Limit:   1/  3, Time:10.95129418
# ConfigID:   2, Epoch:  10, Training Loss: 0.17955730, Validation Loss: 0.18084048,                    Best: 0.18084048, StopCount/Limit:   1/  3, Time:10.55203986
# ConfigID:   2, Epoch:  11, Training Loss: 0.17626701, Validation Loss: 0.17677679,                    Best: 0.17677679, StopCount/Limit:   1/  3, Time:10.43494010
# ConfigID:   2, Epoch:  12, Training Loss: 0.17393597, Validation Loss: 0.17026733,                    Best: 0.17026733, StopCount/Limit:   1/  3, Time:10.59146786
# ConfigID:   2, Epoch:  13, Training Loss: 0.17223148, Validation Loss: 0.17433186,                    Best: 0.17026733, StopCount/Limit:   2/  3, Time:10.54838300
# ConfigID:   2, Epoch:  14, Training Loss: 0.16968420, Validation Loss: 0.17269356,                    Best: 0.17026733, StopCount/Limit:   3/  3, Time:10.54327297
# Gen 0 Run End
# Run   0 Best: 0.08927468351274728, Mean: 0.12429970413384338, ID:1, config: [784   9   5   4   8   6   7   4   4   9  10], updatecount:   2, Generation RunTime: 634.33453798
# Gen 1 Run Start
# Next Gen: [784   9   6   4   9   7   4   7   6   9  10]
# ConfigID:   0, Epoch:   0, Training Loss: 0.29278145, Validation Loss: 0.22115461,                    Best: 0.22115461, StopCount/Limit:   0/  3, Time:27.26339602
# ConfigID:   0, Epoch:   1, Training Loss: 0.20311295, Validation Loss: 0.18972800,                    Best: 0.18972800, StopCount/Limit:   0/  3, Time:11.39096975
# ConfigID:   0, Epoch:   2, Training Loss: 0.18238516, Validation Loss: 0.17641497,                    Best: 0.17641497, StopCount/Limit:   0/  3, Time:11.09942031
# ConfigID:   0, Epoch:   3, Training Loss: 0.17256551, Validation Loss: 0.17207616,                    Best: 0.17207616, StopCount/Limit:   0/  3, Time:10.65360117
# ConfigID:   0, Epoch:   4, Training Loss: 0.16759088, Validation Loss: 0.16698454,                    Best: 0.16698454, StopCount/Limit:   0/  3, Time:10.82540894
# ConfigID:   0, Epoch:   5, Training Loss: 0.16370935, Validation Loss: 0.15935249,                    Best: 0.15935249, StopCount/Limit:   0/  3, Time:10.38349581
# ConfigID:   0, Epoch:   6, Training Loss: 0.16038794, Validation Loss: 0.15909752,                    Best: 0.15909752, StopCount/Limit:   0/  3, Time:11.25377989
# ConfigID:   0, Epoch:   7, Training Loss: 0.15875557, Validation Loss: 0.15681247,                    Best: 0.15681247, StopCount/Limit:   0/  3, Time:10.58862686
# ConfigID:   0, Epoch:   8, Training Loss: 0.15733405, Validation Loss: 0.15596394,                    Best: 0.15596394, StopCount/Limit:   0/  3, Time:10.43634915
# ConfigID:   0, Epoch:   9, Training Loss: 0.15701129, Validation Loss: 0.15446564,                    Best: 0.15446564, StopCount/Limit:   0/  3, Time:11.01359582
# ConfigID:   0, Epoch:  10, Training Loss: 0.16518571, Validation Loss: 0.16266665,                    Best: 0.15446564, StopCount/Limit:   1/  3, Time:11.55348396
# ConfigID:   0, Epoch:  11, Training Loss: 0.16337059, Validation Loss: 0.16369334,                    Best: 0.15446564, StopCount/Limit:   2/  3, Time:9.86757970
# ConfigID:   0, Epoch:  12, Training Loss: 0.15686604, Validation Loss: 0.15056839,                    Best: 0.15056839, StopCount/Limit:   2/  3, Time:10.78783107
# ConfigID:   0, Epoch:  13, Training Loss: 0.15403399, Validation Loss: 0.15342789,                    Best: 0.15056839, StopCount/Limit:   3/  3, Time:10.89169097
# Next Gen: [784   9   5   4   8   6   7   4   6   9  10]
# ConfigID:   1, Epoch:   0, Training Loss: 0.33661776, Validation Loss: 0.32511825,                    Best: 0.32511825, StopCount/Limit:   0/  3, Time:10.71884608
# ConfigID:   1, Epoch:   1, Training Loss: 0.32507367, Validation Loss: 0.32492818,                    Best: 0.32492818, StopCount/Limit:   0/  3, Time:10.79820085
# ConfigID:   1, Epoch:   2, Training Loss: 0.32507465, Validation Loss: 0.32506222,                    Best: 0.32492818, StopCount/Limit:   1/  3, Time:10.49373698
# ConfigID:   1, Epoch:   3, Training Loss: 0.32507465, Validation Loss: 0.32506382,                    Best: 0.32492818, StopCount/Limit:   2/  3, Time:9.69151211
# ConfigID:   1, Epoch:   4, Training Loss: 0.32507702, Validation Loss: 0.32503914,                    Best: 0.32492818, StopCount/Limit:   3/  3, Time:9.65061212
# Next Gen: [784   7   4   5   6   5   6   7   6   7  10]
# ConfigID:   2, Epoch:   0, Training Loss: 0.27529711, Validation Loss: 0.23340018,                    Best: 0.23340018, StopCount/Limit:   0/  3, Time:9.42218399
# ConfigID:   2, Epoch:   1, Training Loss: 0.22158118, Validation Loss: 0.21503516,                    Best: 0.21503516, StopCount/Limit:   0/  3, Time:9.44534922
# ConfigID:   2, Epoch:   2, Training Loss: 0.21244590, Validation Loss: 0.21217044,                    Best: 0.21217044, StopCount/Limit:   0/  3, Time:9.41136098
# ConfigID:   2, Epoch:   3, Training Loss: 0.20836057, Validation Loss: 0.20831354,                    Best: 0.20831354, StopCount/Limit:   0/  3, Time:9.22339892
# ConfigID:   2, Epoch:   4, Training Loss: 0.20601091, Validation Loss: 0.20649374,                    Best: 0.20649374, StopCount/Limit:   0/  3, Time:9.34548903
# ConfigID:   2, Epoch:   5, Training Loss: 0.20381725, Validation Loss: 0.20246556,                    Best: 0.20246556, StopCount/Limit:   0/  3, Time:9.43915606
# ConfigID:   2, Epoch:   6, Training Loss: 0.20184407, Validation Loss: 0.20105264,                    Best: 0.20105264, StopCount/Limit:   0/  3, Time:9.30345082
# ConfigID:   2, Epoch:   7, Training Loss: 0.20104582, Validation Loss: 0.20382977,                    Best: 0.20105264, StopCount/Limit:   1/  3, Time:9.49671912
# ConfigID:   2, Epoch:   8, Training Loss: 0.19995155, Validation Loss: 0.20024617,                    Best: 0.20024617, StopCount/Limit:   1/  3, Time:9.41931081
# ConfigID:   2, Epoch:   9, Training Loss: 0.19885538, Validation Loss: 0.20020323,                    Best: 0.20020323, StopCount/Limit:   1/  3, Time:9.35048294
# ConfigID:   2, Epoch:  10, Training Loss: 0.19836767, Validation Loss: 0.20202910,                    Best: 0.20020323, StopCount/Limit:   2/  3, Time:9.37289810
# ConfigID:   2, Epoch:  11, Training Loss: 0.19751642, Validation Loss: 0.20546155,                    Best: 0.20020323, StopCount/Limit:   3/  3, Time:9.50277400
# Gen 1 Run End
# Run   1 Best: 0.08927468351274728, Mean: 0.12429970413384338, ID:1, config: [784   9   5   4   8   6   7   4   4   9  10], updatecount:   0, Generation RunTime: 332.12894797
# Gen 2 Run Start
# Next Gen: [784   9   6   4   9   7   4   7   6  10]
# ConfigID:   0, Epoch:   0, Training Loss: 0.24266586, Validation Loss: 0.19750240,                    Best: 0.19750240, StopCount/Limit:   0/  3, Time:8.67736316
# ConfigID:   0, Epoch:   1, Training Loss: 0.16272365, Validation Loss: 0.14079832,                    Best: 0.14079832, StopCount/Limit:   0/  3, Time:8.71595526
# ConfigID:   0, Epoch:   2, Training Loss: 0.13213964, Validation Loss: 0.12842373,                    Best: 0.12842373, StopCount/Limit:   0/  3, Time:8.66986203
# ConfigID:   0, Epoch:   3, Training Loss: 0.12357050, Validation Loss: 0.12859670,                    Best: 0.12842373, StopCount/Limit:   1/  3, Time:8.81171203
# ConfigID:   0, Epoch:   4, Training Loss: 0.11712334, Validation Loss: 0.12167029,                    Best: 0.12167029, StopCount/Limit:   1/  3, Time:10.11942315
# ConfigID:   0, Epoch:   5, Training Loss: 0.11179658, Validation Loss: 0.11351185,                    Best: 0.11351185, StopCount/Limit:   1/  3, Time:10.55863214
# ConfigID:   0, Epoch:   6, Training Loss: 0.10822879, Validation Loss: 0.10801746,                    Best: 0.10801746, StopCount/Limit:   1/  3, Time:9.59070182
# ConfigID:   0, Epoch:   7, Training Loss: 0.10441708, Validation Loss: 0.10493161,                    Best: 0.10493161, StopCount/Limit:   1/  3, Time:8.96744990
# ConfigID:   0, Epoch:   8, Training Loss: 0.10101286, Validation Loss: 0.10978007,                    Best: 0.10493161, StopCount/Limit:   2/  3, Time:10.35231590
# ConfigID:   0, Epoch:   9, Training Loss: 0.09817248, Validation Loss: 0.10380082,                    Best: 0.10380082, StopCount/Limit:   2/  3, Time:9.03849626
# ConfigID:   0, Epoch:  10, Training Loss: 0.09688847, Validation Loss: 0.10119472,                    Best: 0.10119472, StopCount/Limit:   2/  3, Time:9.39974499
# ConfigID:   0, Epoch:  11, Training Loss: 0.09434922, Validation Loss: 0.10086072,                    Best: 0.10086072, StopCount/Limit:   2/  3, Time:10.12912202
# ConfigID:   0, Epoch:  12, Training Loss: 0.09345150, Validation Loss: 0.09828349,                    Best: 0.09828349, StopCount/Limit:   2/  3, Time:9.92681289
# ConfigID:   0, Epoch:  13, Training Loss: 0.09312466, Validation Loss: 0.09788115,                    Best: 0.09788115, StopCount/Limit:   2/  3, Time:9.98690081
# ConfigID:   0, Epoch:  14, Training Loss: 0.09170534, Validation Loss: 0.09665288,                    Best: 0.09665288, StopCount/Limit:   2/  3, Time:10.04936695
# ConfigID:   0, Epoch:  15, Training Loss: 0.08993909, Validation Loss: 0.09747678,                    Best: 0.09665288, StopCount/Limit:   3/  3, Time:9.22052217
# Next Gen: [784   9   5   4   8   6   7   4   4   9  10]
# ConfigID:   1, Epoch:   0, Training Loss: 0.28162462, Validation Loss: 0.23078186,                    Best: 0.23078186, StopCount/Limit:   0/  3, Time:10.90731597
# ConfigID:   1, Epoch:   1, Training Loss: 0.21628580, Validation Loss: 0.21051123,                    Best: 0.21051123, StopCount/Limit:   0/  3, Time:10.58740139
# ConfigID:   1, Epoch:   2, Training Loss: 0.20651347, Validation Loss: 0.20442830,                    Best: 0.20442830, StopCount/Limit:   0/  3, Time:9.59518814
# ConfigID:   1, Epoch:   3, Training Loss: 0.20140995, Validation Loss: 0.20005380,                    Best: 0.20005380, StopCount/Limit:   0/  3, Time:9.56783390
# ConfigID:   1, Epoch:   4, Training Loss: 0.19552907, Validation Loss: 0.20013261,                    Best: 0.20005380, StopCount/Limit:   1/  3, Time:9.53359389
# ConfigID:   1, Epoch:   5, Training Loss: 0.19329157, Validation Loss: 0.19190362,                    Best: 0.19190362, StopCount/Limit:   1/  3, Time:9.59127498
# ConfigID:   1, Epoch:   6, Training Loss: 0.18684956, Validation Loss: 0.18834295,                    Best: 0.18834295, StopCount/Limit:   1/  3, Time:9.63725209
# ConfigID:   1, Epoch:   7, Training Loss: 0.18352085, Validation Loss: 0.19501046,                    Best: 0.18834295, StopCount/Limit:   2/  3, Time:9.45504522
# ConfigID:   1, Epoch:   8, Training Loss: 0.17963610, Validation Loss: 0.18311871,                    Best: 0.18311871, StopCount/Limit:   2/  3, Time:10.44430995
# ConfigID:   1, Epoch:   9, Training Loss: 0.17667730, Validation Loss: 0.17337702,                    Best: 0.17337702, StopCount/Limit:   2/  3, Time:10.69468594
# ConfigID:   1, Epoch:  10, Training Loss: 0.17529694, Validation Loss: 0.17247196,                    Best: 0.17247196, StopCount/Limit:   2/  3, Time:10.57192707
# ConfigID:   1, Epoch:  11, Training Loss: 0.18870712, Validation Loss: 0.17968043,                    Best: 0.17247196, StopCount/Limit:   3/  3, Time:10.29559588
# Next Gen: [784   7   4   5   5   4  10   4   4   8  10]
# ConfigID:   2, Epoch:   0, Training Loss: 0.24724825, Validation Loss: 0.17319452,                    Best: 0.17319452, StopCount/Limit:   0/  3, Time:10.22014594
# ConfigID:   2, Epoch:   1, Training Loss: 0.15861707, Validation Loss: 0.15000818,                    Best: 0.15000818, StopCount/Limit:   0/  3, Time:10.45952415
# ConfigID:   2, Epoch:   2, Training Loss: 0.14129031, Validation Loss: 0.13422717,                    Best: 0.13422717, StopCount/Limit:   0/  3, Time:9.36576891
# ConfigID:   2, Epoch:   3, Training Loss: 0.13167886, Validation Loss: 0.13211045,                    Best: 0.13211045, StopCount/Limit:   0/  3, Time:9.36818099
# ConfigID:   2, Epoch:   4, Training Loss: 0.12839277, Validation Loss: 0.12653045,                    Best: 0.12653045, StopCount/Limit:   0/  3, Time:9.42178392
# ConfigID:   2, Epoch:   5, Training Loss: 0.12550844, Validation Loss: 0.13617516,                    Best: 0.12653045, StopCount/Limit:   1/  3, Time:9.36366796
# ConfigID:   2, Epoch:   6, Training Loss: 0.12356231, Validation Loss: 0.12526132,                    Best: 0.12526132, StopCount/Limit:   1/  3, Time:9.86872387
# ConfigID:   2, Epoch:   7, Training Loss: 0.12208695, Validation Loss: 0.12109280,                    Best: 0.12109280, StopCount/Limit:   1/  3, Time:10.48557520
# ConfigID:   2, Epoch:   8, Training Loss: 0.12098538, Validation Loss: 0.13066504,                    Best: 0.12109280, StopCount/Limit:   2/  3, Time:11.30668306
# ConfigID:   2, Epoch:   9, Training Loss: 0.11938508, Validation Loss: 0.12220919,                    Best: 0.12109280, StopCount/Limit:   3/  3, Time:11.31908298
# Gen 2 Run End
# Run   2 Best: 0.08927468351274728, Mean: 0.10234012050119538, ID:1, config: [784   9   5   4   8   6   7   4   4   9  10], updatecount:   2, Generation RunTime: 374.30364919
# Gen 3 Run Start
# Next Gen: [784   7   4   4   5   4   4   4   4   9  10]
# ConfigID:   0, Epoch:   0, Training Loss: 0.30025862, Validation Loss: 0.25997520,                    Best: 0.25997520, StopCount/Limit:   0/  3, Time:14.33091784
# ConfigID:   0, Epoch:   1, Training Loss: 0.25865569, Validation Loss: 0.25584480,                    Best: 0.25584480, StopCount/Limit:   0/  3, Time:10.60071492
# ConfigID:   0, Epoch:   2, Training Loss: 0.25475885, Validation Loss: 0.25158434,                    Best: 0.25158434, StopCount/Limit:   0/  3, Time:12.90682197
# ConfigID:   0, Epoch:   3, Training Loss: 0.23523946, Validation Loss: 0.20731347,                    Best: 0.20731347, StopCount/Limit:   0/  3, Time:10.51865983
# ConfigID:   0, Epoch:   4, Training Loss: 0.20287332, Validation Loss: 0.19529262,                    Best: 0.19529262, StopCount/Limit:   0/  3, Time:12.57062817
# ConfigID:   0, Epoch:   5, Training Loss: 0.17889955, Validation Loss: 0.16878246,                    Best: 0.16878246, StopCount/Limit:   0/  3, Time:11.72835994
# ConfigID:   0, Epoch:   6, Training Loss: 0.15779451, Validation Loss: 0.15551393,                    Best: 0.15551393, StopCount/Limit:   0/  3, Time:11.09023571
# ConfigID:   0, Epoch:   7, Training Loss: 0.14765988, Validation Loss: 0.14222307,                    Best: 0.14222307, StopCount/Limit:   0/  3, Time:13.62089419
# ConfigID:   0, Epoch:   8, Training Loss: 0.14085626, Validation Loss: 0.13674255,                    Best: 0.13674255, StopCount/Limit:   0/  3, Time:10.78837013
# ConfigID:   0, Epoch:   9, Training Loss: 0.13504982, Validation Loss: 0.13687095,                    Best: 0.13674255, StopCount/Limit:   1/  3, Time:10.13103509
# ConfigID:   0, Epoch:  10, Training Loss: 0.13344704, Validation Loss: 0.13499684,                    Best: 0.13499684, StopCount/Limit:   1/  3, Time:10.13281322
# ConfigID:   0, Epoch:  11, Training Loss: 0.13025385, Validation Loss: 0.12930267,                    Best: 0.12930267, StopCount/Limit:   1/  3, Time:10.07499695
# ConfigID:   0, Epoch:  12, Training Loss: 0.12676339, Validation Loss: 0.12944990,                    Best: 0.12930267, StopCount/Limit:   2/  3, Time:10.00193095
# ConfigID:   0, Epoch:  13, Training Loss: 0.12451375, Validation Loss: 0.12688457,                    Best: 0.12688457, StopCount/Limit:   2/  3, Time:10.83527923
# ConfigID:   0, Epoch:  14, Training Loss: 0.12326519, Validation Loss: 0.12699297,                    Best: 0.12688457, StopCount/Limit:   3/  3, Time:12.74680305
# Next Gen: [784   9   5   4   8   6   7   4   4   9  10]
# ConfigID:   1, Epoch:   0, Training Loss: 0.25036459, Validation Loss: 0.20105030,                    Best: 0.20105030, StopCount/Limit:   0/  3, Time:10.61305428
# ConfigID:   1, Epoch:   1, Training Loss: 0.19800262, Validation Loss: 0.19038378,                    Best: 0.19038378, StopCount/Limit:   0/  3, Time:13.48361588
# ConfigID:   1, Epoch:   2, Training Loss: 0.18415754, Validation Loss: 0.17830400,                    Best: 0.17830400, StopCount/Limit:   0/  3, Time:12.06704402
# ConfigID:   1, Epoch:   3, Training Loss: 0.17529530, Validation Loss: 0.17928258,                    Best: 0.17830400, StopCount/Limit:   1/  3, Time:12.81202412
# ConfigID:   1, Epoch:   4, Training Loss: 0.17137160, Validation Loss: 0.17022586,                    Best: 0.17022586, StopCount/Limit:   1/  3, Time:10.44537497
# ConfigID:   1, Epoch:   5, Training Loss: 0.16657659, Validation Loss: 0.16490644,                    Best: 0.16490644, StopCount/Limit:   1/  3, Time:12.46815681
# ConfigID:   1, Epoch:   6, Training Loss: 0.16144736, Validation Loss: 0.17569309,                    Best: 0.16490644, StopCount/Limit:   2/  3, Time:10.45824075
# ConfigID:   1, Epoch:   7, Training Loss: 0.15860499, Validation Loss: 0.15784682,                    Best: 0.15784682, StopCount/Limit:   2/  3, Time:10.41377187
# ConfigID:   1, Epoch:   8, Training Loss: 0.15548946, Validation Loss: 0.17284230,                    Best: 0.15784682, StopCount/Limit:   3/  3, Time:10.78931808
# Next Gen: [784   7   4   5   5   4  10   4   4   7  10]
# ConfigID:   2, Epoch:   0, Training Loss: 0.37200808, Validation Loss: 0.32500356,                    Best: 0.32500356, StopCount/Limit:   0/  3, Time:10.55458999
# ConfigID:   2, Epoch:   1, Training Loss: 0.32495353, Validation Loss: 0.32492317,                    Best: 0.32492317, StopCount/Limit:   0/  3, Time:11.72882104
# ConfigID:   2, Epoch:   2, Training Loss: 0.32494811, Validation Loss: 0.32491367,                    Best: 0.32491367, StopCount/Limit:   0/  3, Time:11.18947983
# ConfigID:   2, Epoch:   3, Training Loss: 0.32495702, Validation Loss: 0.32490481,                    Best: 0.32490481, StopCount/Limit:   0/  3, Time:12.01560903
# ConfigID:   2, Epoch:   4, Training Loss: 0.32495081, Validation Loss: 0.32492358,                    Best: 0.32490481, StopCount/Limit:   1/  3, Time:13.45001984
# ConfigID:   2, Epoch:   5, Training Loss: 0.32495509, Validation Loss: 0.32491603,                    Best: 0.32490481, StopCount/Limit:   2/  3, Time:14.06181979
# ConfigID:   2, Epoch:   6, Training Loss: 0.32495126, Validation Loss: 0.32494559,                    Best: 0.32490481, StopCount/Limit:   3/  3, Time:16.48795795
# Gen 3 Run End
# Run   3 Best: 0.08927468351274728, Mean: 0.10234012050119538, ID:1, config: [784   9   5   4   8   6   7   4   4   9  10], updatecount:   0, Generation RunTime: 365.14979291
# Gen 4 Run Start
# Next Gen: [784   9   6   4   9   7   4   7   6  10]
# ConfigID:   0, Epoch:   0, Training Loss: 0.28517835, Validation Loss: 0.23288181,                    Best: 0.23288181, StopCount/Limit:   0/  3, Time:11.69415617
# ConfigID:   0, Epoch:   1, Training Loss: 0.21639944, Validation Loss: 0.21428759,                    Best: 0.21428759, StopCount/Limit:   0/  3, Time:13.77851391
# ConfigID:   0, Epoch:   2, Training Loss: 0.19971700, Validation Loss: 0.19134808,                    Best: 0.19134808, StopCount/Limit:   0/  3, Time:11.81179476
# ConfigID:   0, Epoch:   3, Training Loss: 0.19102053, Validation Loss: 0.18500221,                    Best: 0.18500221, StopCount/Limit:   0/  3, Time:9.95782900
# ConfigID:   0, Epoch:   4, Training Loss: 0.18566670, Validation Loss: 0.18087144,                    Best: 0.18087144, StopCount/Limit:   0/  3, Time:9.15299773
# ConfigID:   0, Epoch:   5, Training Loss: 0.18073380, Validation Loss: 0.17948710,                    Best: 0.17948710, StopCount/Limit:   0/  3, Time:10.53557897
# ConfigID:   0, Epoch:   6, Training Loss: 0.17694485, Validation Loss: 0.17634493,                    Best: 0.17634493, StopCount/Limit:   0/  3, Time:11.53866482
# ConfigID:   0, Epoch:   7, Training Loss: 0.17319631, Validation Loss: 0.17209270,                    Best: 0.17209270, StopCount/Limit:   0/  3, Time:9.44927526
# ConfigID:   0, Epoch:   8, Training Loss: 0.17146053, Validation Loss: 0.17155269,                    Best: 0.17155269, StopCount/Limit:   0/  3, Time:9.75207376
# ConfigID:   0, Epoch:   9, Training Loss: 0.16554729, Validation Loss: 0.16678802,                    Best: 0.16678802, StopCount/Limit:   0/  3, Time:10.17557478
# ConfigID:   0, Epoch:  10, Training Loss: 0.16093457, Validation Loss: 0.15941218,                    Best: 0.15941218, StopCount/Limit:   0/  3, Time:10.84610891
# ConfigID:   0, Epoch:  11, Training Loss: 0.15681384, Validation Loss: 0.15774042,                    Best: 0.15774042, StopCount/Limit:   0/  3, Time:10.76700115
# ConfigID:   0, Epoch:  12, Training Loss: 0.15313601, Validation Loss: 0.15397014,                    Best: 0.15397014, StopCount/Limit:   0/  3, Time:11.08541512
# ConfigID:   0, Epoch:  13, Training Loss: 0.14922475, Validation Loss: 0.14692183,                    Best: 0.14692183, StopCount/Limit:   0/  3, Time:9.85361505
# ConfigID:   0, Epoch:  14, Training Loss: 0.14063426, Validation Loss: 0.13210715,                    Best: 0.13210715, StopCount/Limit:   0/  3, Time:10.60534215
# ConfigID:   0, Epoch:  15, Training Loss: 0.13041859, Validation Loss: 0.12533102,                    Best: 0.12533102, StopCount/Limit:   0/  3, Time:11.41627216
# ConfigID:   0, Epoch:  16, Training Loss: 0.12236995, Validation Loss: 0.11781752,                    Best: 0.11781752, StopCount/Limit:   0/  3, Time:10.82210279
# ConfigID:   0, Epoch:  17, Training Loss: 0.11977635, Validation Loss: 0.11712101,                    Best: 0.11712101, StopCount/Limit:   0/  3, Time:11.68579078
# ConfigID:   0, Epoch:  18, Training Loss: 0.11632635, Validation Loss: 0.10516188,                    Best: 0.10516188, StopCount/Limit:   0/  3, Time:13.21513104
# ConfigID:   0, Epoch:  19, Training Loss: 0.11039646, Validation Loss: 0.10747943,                    Best: 0.10516188, StopCount/Limit:   1/  3, Time:13.47238612
# ConfigID:   0, Epoch:  20, Training Loss: 0.10872659, Validation Loss: 0.10954862,                    Best: 0.10516188, StopCount/Limit:   2/  3, Time:11.61277795
# ConfigID:   0, Epoch:  21, Training Loss: 0.10582111, Validation Loss: 0.10486692,                    Best: 0.10486692, StopCount/Limit:   2/  3, Time:13.07874703
# ConfigID:   0, Epoch:  22, Training Loss: 0.10417000, Validation Loss: 0.10968537,                    Best: 0.10486692, StopCount/Limit:   3/  3, Time:12.21755886
# Next Gen: [784   9   5   4   8   6   7   4   4   9  10]
# ConfigID:   1, Epoch:   0, Training Loss: 0.33583861, Validation Loss: 0.32495169,                    Best: 0.32495169, StopCount/Limit:   0/  3, Time:14.45733976
# ConfigID:   1, Epoch:   1, Training Loss: 0.32504163, Validation Loss: 0.32495209,                    Best: 0.32495169, StopCount/Limit:   1/  3, Time:20.94710708
# ConfigID:   1, Epoch:   2, Training Loss: 0.32502597, Validation Loss: 0.32495519,                    Best: 0.32495169, StopCount/Limit:   2/  3, Time:17.82061291
# ConfigID:   1, Epoch:   3, Training Loss: 0.32503609, Validation Loss: 0.32501008,                    Best: 0.32495169, StopCount/Limit:   3/  3, Time:15.09892583
# Next Gen: [784   7   4   5   5   4   7   6   5   7  10]
# ConfigID:   2, Epoch:   0, Training Loss: 0.26342518, Validation Loss: 0.22302201,                    Best: 0.22302201, StopCount/Limit:   0/  3, Time:13.29497600
# ConfigID:   2, Epoch:   1, Training Loss: 0.21931937, Validation Loss: 0.21545295,                    Best: 0.21545295, StopCount/Limit:   0/  3, Time:14.64340377
# ConfigID:   2, Epoch:   2, Training Loss: 0.21317356, Validation Loss: 0.21021641,                    Best: 0.21021641, StopCount/Limit:   0/  3, Time:13.57435703
# ConfigID:   2, Epoch:   3, Training Loss: 0.20725321, Validation Loss: 0.20199204,                    Best: 0.20199204, StopCount/Limit:   0/  3, Time:10.96087766
# ConfigID:   2, Epoch:   4, Training Loss: 0.20341546, Validation Loss: 0.20435494,                    Best: 0.20199204, StopCount/Limit:   1/  3, Time:12.81335282
# ConfigID:   2, Epoch:   5, Training Loss: 0.20132463, Validation Loss: 0.19556891,                    Best: 0.19556891, StopCount/Limit:   1/  3, Time:11.61731195
# ConfigID:   2, Epoch:   6, Training Loss: 0.19749282, Validation Loss: 0.19297214,                    Best: 0.19297214, StopCount/Limit:   1/  3, Time:12.43265939
# ConfigID:   2, Epoch:   7, Training Loss: 0.19545539, Validation Loss: 0.19285364,                    Best: 0.19285364, StopCount/Limit:   1/  3, Time:12.44476199
# ConfigID:   2, Epoch:   8, Training Loss: 0.19473006, Validation Loss: 0.19305670,                    Best: 0.19285364, StopCount/Limit:   2/  3, Time:11.81129599
# ConfigID:   2, Epoch:   9, Training Loss: 0.20128160, Validation Loss: 0.20015068,                    Best: 0.19285364, StopCount/Limit:   3/  3, Time:13.23502898
# Gen 4 Run End
# Run   4 Best: 0.08927468351274728, Mean: 0.10234012050119538, ID:1, config: [784   9   5   4   8   6   7   4   4   9  10], updatecount:   0, Generation RunTime: 453.71086621
# Gen 5 Run Start
# Next Gen: [784   9   6   4   9   7   4   7   6   9  10]
# ConfigID:   0, Epoch:   0, Training Loss: 0.25531643, Validation Loss: 0.18095192,                    Best: 0.18095192, StopCount/Limit:   0/  3, Time:14.35367775
# ConfigID:   0, Epoch:   1, Training Loss: 0.17089461, Validation Loss: 0.15911890,                    Best: 0.15911890, StopCount/Limit:   0/  3, Time:13.83548379
# ConfigID:   0, Epoch:   2, Training Loss: 0.15925690, Validation Loss: 0.14779347,                    Best: 0.14779347, StopCount/Limit:   0/  3, Time:11.45141315
# ConfigID:   0, Epoch:   3, Training Loss: 0.15076692, Validation Loss: 0.14084009,                    Best: 0.14084009, StopCount/Limit:   0/  3, Time:11.02427506
# ConfigID:   0, Epoch:   4, Training Loss: 0.14419077, Validation Loss: 0.12992833,                    Best: 0.12992833, StopCount/Limit:   0/  3, Time:11.27426815
# ConfigID:   0, Epoch:   5, Training Loss: 0.13105219, Validation Loss: 0.12145038,                    Best: 0.12145038, StopCount/Limit:   0/  3, Time:10.65633726
# ConfigID:   0, Epoch:   6, Training Loss: 0.12439446, Validation Loss: 0.12084819,                    Best: 0.12084819, StopCount/Limit:   0/  3, Time:11.94131184
# ConfigID:   0, Epoch:   7, Training Loss: 0.12132415, Validation Loss: 0.11551292,                    Best: 0.11551292, StopCount/Limit:   0/  3, Time:11.16298079
# ConfigID:   0, Epoch:   8, Training Loss: 0.11823818, Validation Loss: 0.11505749,                    Best: 0.11505749, StopCount/Limit:   0/  3, Time:11.39231420
# ConfigID:   0, Epoch:   9, Training Loss: 0.12752143, Validation Loss: 0.13369768,                    Best: 0.11505749, StopCount/Limit:   1/  3, Time:10.49725294
# ConfigID:   0, Epoch:  10, Training Loss: 0.12862758, Validation Loss: 0.12546940,                    Best: 0.11505749, StopCount/Limit:   2/  3, Time:9.90102291
# ConfigID:   0, Epoch:  11, Training Loss: 0.11912471, Validation Loss: 0.11393242,                    Best: 0.11393242, StopCount/Limit:   2/  3, Time:9.82655382
# ConfigID:   0, Epoch:  12, Training Loss: 0.11704208, Validation Loss: 0.12225913,                    Best: 0.11393242, StopCount/Limit:   3/  3, Time:9.85513687
# Next Gen: [784   9   5   4   6   6   7   4   4   9  10]
# ConfigID:   1, Epoch:   0, Training Loss: 0.33492959, Validation Loss: 0.32529734,                    Best: 0.32529734, StopCount/Limit:   0/  3, Time:9.60793018
# ConfigID:   1, Epoch:   1, Training Loss: 0.32519786, Validation Loss: 0.32517644,                    Best: 0.32517644, StopCount/Limit:   0/  3, Time:9.67268491
# ConfigID:   1, Epoch:   2, Training Loss: 0.32517389, Validation Loss: 0.32516782,                    Best: 0.32516782, StopCount/Limit:   0/  3, Time:10.07634091
# ConfigID:   1, Epoch:   3, Training Loss: 0.32517686, Validation Loss: 0.32522641,                    Best: 0.32516782, StopCount/Limit:   1/  3, Time:9.69745612
# ConfigID:   1, Epoch:   4, Training Loss: 0.32512111, Validation Loss: 0.32506403,                    Best: 0.32506403, StopCount/Limit:   1/  3, Time:9.64036298
# ConfigID:   1, Epoch:   5, Training Loss: 0.32513725, Validation Loss: 0.32498419,                    Best: 0.32498419, StopCount/Limit:   1/  3, Time:9.55263591
# ConfigID:   1, Epoch:   6, Training Loss: 0.32512731, Validation Loss: 0.32514280,                    Best: 0.32498419, StopCount/Limit:   2/  3, Time:9.71701217
# ConfigID:   1, Epoch:   7, Training Loss: 0.32512902, Validation Loss: 0.32511412,                    Best: 0.32498419, StopCount/Limit:   3/  3, Time:9.81444716
# Next Gen: [784   7   4   5   5   4  10   4   4   8  10]
# ConfigID:   2, Epoch:   0, Training Loss: 0.28025437, Validation Loss: 0.25543894,                    Best: 0.25543894, StopCount/Limit:   0/  3, Time:9.66353297
# ConfigID:   2, Epoch:   1, Training Loss: 0.25651060, Validation Loss: 0.25548195,                    Best: 0.25543894, StopCount/Limit:   1/  3, Time:9.59513688
# ConfigID:   2, Epoch:   2, Training Loss: 0.25118054, Validation Loss: 0.23450538,                    Best: 0.23450538, StopCount/Limit:   1/  3, Time:9.61684203
# ConfigID:   2, Epoch:   3, Training Loss: 0.22585029, Validation Loss: 0.22175103,                    Best: 0.22175103, StopCount/Limit:   1/  3, Time:9.56026912
# ConfigID:   2, Epoch:   4, Training Loss: 0.21400573, Validation Loss: 0.21448048,                    Best: 0.21448048, StopCount/Limit:   1/  3, Time:9.78255916
# ConfigID:   2, Epoch:   5, Training Loss: 0.20931763, Validation Loss: 0.20815654,                    Best: 0.20815654, StopCount/Limit:   1/  3, Time:10.10649300
# ConfigID:   2, Epoch:   6, Training Loss: 0.20244195, Validation Loss: 0.20116643,                    Best: 0.20116643, StopCount/Limit:   1/  3, Time:9.59907484
# ConfigID:   2, Epoch:   7, Training Loss: 0.19639536, Validation Loss: 0.19513762,                    Best: 0.19513762, StopCount/Limit:   1/  3, Time:10.30148816
# ConfigID:   2, Epoch:   8, Training Loss: 0.19376601, Validation Loss: 0.19656107,                    Best: 0.19513762, StopCount/Limit:   2/  3, Time:11.25741816
# ConfigID:   2, Epoch:   9, Training Loss: 0.19239015, Validation Loss: 0.19499956,                    Best: 0.19499956, StopCount/Limit:   2/  3, Time:11.33593988
# ConfigID:   2, Epoch:  10, Training Loss: 0.19239697, Validation Loss: 0.19549489,                    Best: 0.19499956, StopCount/Limit:   3/  3, Time:9.65526509
# Gen 5 Run End
# Run   5 Best: 0.08927468351274728, Mean: 0.10234012050119538, ID:1, config: [784   9   5   4   8   6   7   4   4   9  10], updatecount:   0, Generation RunTime: 335.45378685
# Gen 6 Run Start
# Next Gen: [784   7   5   4   6   5   6   7   6  10]
# ConfigID:   0, Epoch:   0, Training Loss: 0.25595084, Validation Loss: 0.20374286,                    Best: 0.20374286, StopCount/Limit:   0/  3, Time:8.68878412
# ...
# ConfigID:   2, Epoch:   2, Training Loss: 0.19907469, Validation Loss: 0.19964752,                    Best: 0.19964752, StopCount/Limit:   0/  3, Time:11.53588986
# ConfigID:   2, Epoch:   3, Training Loss: 0.19151297, Validation Loss: 0.18897281,                    Best: 0.18897281, StopCount/Limit:   0/  3, Time:11.38447905
# ConfigID:   2, Epoch:   4, Training Loss: 0.18367011, Validation Loss: 0.18348570,                    Best: 0.18348570, StopCount/Limit:   0/  3, Time:13.19985890
# ConfigID:   2, Epoch:   5, Training Loss: 0.18003990, Validation Loss: 0.18415784,                    Best: 0.18348570, StopCount/Limit:   1/  3, Time:12.51121712
# ConfigID:   2, Epoch:   6, Training Loss: 0.17429880, Validation Loss: 0.18090008,                    Best: 0.18090008, StopCount/Limit:   1/  3, Time:10.12309504
# ConfigID:   2, Epoch:   7, Training Loss: 0.16843076, Validation Loss: 0.16585229,                    Best: 0.16585229, StopCount/Limit:   1/  3, Time:9.80737424
# ConfigID:   2, Epoch:   8, Training Loss: 0.16009174, Validation Loss: 0.15942880,                    Best: 0.15942880, StopCount/Limit:   1/  3, Time:15.40599704
# ConfigID:   2, Epoch:   9, Training Loss: 0.15260751, Validation Loss: 0.15921393,                    Best: 0.15921393, StopCount/Limit:   1/  3, Time:14.06282187
# ConfigID:   2, Epoch:  10, Training Loss: 0.15069765, Validation Loss: 0.15640069,                    Best: 0.15640069, StopCount/Limit:   1/  3, Time:13.85039091
# ConfigID:   2, Epoch:  11, Training Loss: 0.14398101, Validation Loss: 0.14423586,                    Best: 0.14423586, StopCount/Limit:   1/  3, Time:10.61306095
# ConfigID:   2, Epoch:  12, Training Loss: 0.13769891, Validation Loss: 0.14026973,                    Best: 0.14026973, StopCount/Limit:   1/  3, Time:10.41073799
# ConfigID:   2, Epoch:  13, Training Loss: 0.13620917, Validation Loss: 0.13734009,                    Best: 0.13734009, StopCount/Limit:   1/  3, Time:10.44764519
# ConfigID:   2, Epoch:  14, Training Loss: 0.13114189, Validation Loss: 0.13198795,                    Best: 0.13198795, StopCount/Limit:   1/  3, Time:10.41245508
# ConfigID:   2, Epoch:  15, Training Loss: 0.12901749, Validation Loss: 0.13372693,                    Best: 0.13198795, StopCount/Limit:   2/  3, Time:10.33776903
# ConfigID:   2, Epoch:  16, Training Loss: 0.12623983, Validation Loss: 0.13000214,                    Best: 0.13000214, StopCount/Limit:   2/  3, Time:10.31936789
# ConfigID:   2, Epoch:  17, Training Loss: 0.12522394, Validation Loss: 0.12672177,                    Best: 0.12672177, StopCount/Limit:   2/  3, Time:10.22685003
# ConfigID:   2, Epoch:  18, Training Loss: 0.12276363, Validation Loss: 0.12956355,                    Best: 0.12672177, StopCount/Limit:   3/  3, Time:10.24866080
# Gen 7 Run End
# Run   7 Best: 0.08927468351274728, Mean: 0.10234012050119538, ID:1, config: [784   9   5   4   8   6   7   4   4   9  10], updatecount:   0, Generation RunTime: 516.55333614
# Gen 8 Run Start
# Next Gen: [784   9   6   4   9   7   4   7   6  10]
# ConfigID:   0, Epoch:   0, Training Loss: 0.30365868, Validation Loss: 0.25708874,                    Best: 0.25708874, StopCount/Limit:   0/  3, Time:11.88874388
# ConfigID:   0, Epoch:   1, Training Loss: 0.24326739, Validation Loss: 0.23266932,                    Best: 0.23266932, StopCount/Limit:   0/  3, Time:13.55020404
# ConfigID:   0, Epoch:   2, Training Loss: 0.21818421, Validation Loss: 0.20866155,                    Best: 0.20866155, StopCount/Limit:   0/  3, Time:12.13408208
# ConfigID:   0, Epoch:   3, Training Loss: 0.19823655, Validation Loss: 0.20047952,                    Best: 0.20047952, StopCount/Limit:   0/  3, Time:10.95905900
# ConfigID:   0, Epoch:   4, Training Loss: 0.19150698, Validation Loss: 0.19647584,                    Best: 0.19647584, StopCount/Limit:   0/  3, Time:16.01880622
# ConfigID:   0, Epoch:   5, Training Loss: 0.18506191, Validation Loss: 0.18839253,                    Best: 0.18839253, StopCount/Limit:   0/  3, Time:14.09756088
# ConfigID:   0, Epoch:   6, Training Loss: 0.17101948, Validation Loss: 0.17011733,                    Best: 0.17011733, StopCount/Limit:   0/  3, Time:13.33642697
# ConfigID:   0, Epoch:   7, Training Loss: 0.15829975, Validation Loss: 0.16132650,                    Best: 0.16132650, StopCount/Limit:   0/  3, Time:11.38992906
# ConfigID:   0, Epoch:   8, Training Loss: 0.15346222, Validation Loss: 0.15608721,                    Best: 0.15608721, StopCount/Limit:   0/  3, Time:11.42141604
# ConfigID:   0, Epoch:   9, Training Loss: 0.15114350, Validation Loss: 0.16477710,                    Best: 0.15608721, StopCount/Limit:   1/  3, Time:10.45116711
# ConfigID:   0, Epoch:  10, Training Loss: 0.14346464, Validation Loss: 0.13910406,                    Best: 0.13910406, StopCount/Limit:   1/  3, Time:10.84323597
# ConfigID:   0, Epoch:  11, Training Loss: 0.12865826, Validation Loss: 0.12741674,                    Best: 0.12741674, StopCount/Limit:   1/  3, Time:9.04549408
# ConfigID:   0, Epoch:  12, Training Loss: 0.12013874, Validation Loss: 0.12132875,                    Best: 0.12132875, StopCount/Limit:   1/  3, Time:9.24524689
# ConfigID:   0, Epoch:  13, Training Loss: 0.11323147, Validation Loss: 0.11069466,                    Best: 0.11069466, StopCount/Limit:   1/  3, Time:11.71980882
# ConfigID:   0, Epoch:  14, Training Loss: 0.10719455, Validation Loss: 0.11136289,                    Best: 0.11069466, StopCount/Limit:   2/  3, Time:11.26212311
# ConfigID:   0, Epoch:  15, Training Loss: 0.10355087, Validation Loss: 0.10354289,                    Best: 0.10354289, StopCount/Limit:   2/  3, Time:15.29308391
# ConfigID:   0, Epoch:  16, Training Loss: 0.10068746, Validation Loss: 0.10117852,                    Best: 0.10117852, StopCount/Limit:   2/  3, Time:11.64427304
# ConfigID:   0, Epoch:  17, Training Loss: 0.09790506, Validation Loss: 0.10593521,                    Best: 0.10117852, StopCount/Limit:   3/  3, Time:9.78110099
# Next Gen: [784   7   4   4   5   4   7   4   4   9  10]
# ConfigID:   1, Epoch:   0, Training Loss: 0.29191978, Validation Loss: 0.21405897,                    Best: 0.21405897, StopCount/Limit:   0/  3, Time:9.65856004
# ConfigID:   1, Epoch:   1, Training Loss: 0.20104760, Validation Loss: 0.19389500,                    Best: 0.19389500, StopCount/Limit:   0/  3, Time:9.39136195
# ConfigID:   1, Epoch:   2, Training Loss: 0.19097282, Validation Loss: 0.19143826,                    Best: 0.19143826, StopCount/Limit:   0/  3, Time:9.55794096
# ConfigID:   1, Epoch:   3, Training Loss: 0.18739008, Validation Loss: 0.19362435,                    Best: 0.19143826, StopCount/Limit:   1/  3, Time:9.36747694
# ConfigID:   1, Epoch:   4, Training Loss: 0.18289237, Validation Loss: 0.18771379,                    Best: 0.18771379, StopCount/Limit:   1/  3, Time:9.41702008
# ConfigID:   1, Epoch:   5, Training Loss: 0.17611727, Validation Loss: 0.17907586,                    Best: 0.17907586, StopCount/Limit:   1/  3, Time:9.26295877
# ConfigID:   1, Epoch:   6, Training Loss: 0.16940570, Validation Loss: 0.17513286,                    Best: 0.17513286, StopCount/Limit:   1/  3, Time:10.03250790
# ConfigID:   1, Epoch:   7, Training Loss: 0.16486355, Validation Loss: 0.17769431,                    Best: 0.17513286, StopCount/Limit:   2/  3, Time:11.76402497
# ConfigID:   1, Epoch:   8, Training Loss: 0.16228725, Validation Loss: 0.16780336,                    Best: 0.16780336, StopCount/Limit:   2/  3, Time:10.35054278
# ConfigID:   1, Epoch:   9, Training Loss: 0.15886000, Validation Loss: 0.16157749,                    Best: 0.16157749, StopCount/Limit:   2/  3, Time:9.89941907
# ConfigID:   1, Epoch:  10, Training Loss: 0.15321327, Validation Loss: 0.15804191,                    Best: 0.15804191, StopCount/Limit:   2/  3, Time:11.17533231
# ConfigID:   1, Epoch:  11, Training Loss: 0.15037498, Validation Loss: 0.15915729,                    Best: 0.15804191, StopCount/Limit:   3/  3, Time:11.23452282
# Next Gen: [784   7   4   5   5   4   7   6   5   7  10]
# ConfigID:   2, Epoch:   0, Training Loss: 0.28207702, Validation Loss: 0.23328325,                    Best: 0.23328325, StopCount/Limit:   0/  3, Time:11.92147708
# ConfigID:   2, Epoch:   1, Training Loss: 0.23140654, Validation Loss: 0.22636695,                    Best: 0.22636695, StopCount/Limit:   0/  3, Time:13.71916914
# ConfigID:   2, Epoch:   2, Training Loss: 0.22548356, Validation Loss: 0.22417596,                    Best: 0.22417596, StopCount/Limit:   0/  3, Time:12.01420307
# ConfigID:   2, Epoch:   3, Training Loss: 0.22414978, Validation Loss: 0.22208000,                    Best: 0.22208000, StopCount/Limit:   0/  3, Time:11.45635390
# ConfigID:   2, Epoch:   4, Training Loss: 0.22020369, Validation Loss: 0.22959161,                    Best: 0.22208000, StopCount/Limit:   1/  3, Time:12.46541619
# ConfigID:   2, Epoch:   5, Training Loss: 0.21963684, Validation Loss: 0.22253096,                    Best: 0.22208000, StopCount/Limit:   2/  3, Time:15.39503217
# ConfigID:   2, Epoch:   6, Training Loss: 0.21992896, Validation Loss: 0.21770786,                    Best: 0.21770786, StopCount/Limit:   2/  3, Time:10.58590961
# ConfigID:   2, Epoch:   7, Training Loss: 0.21930411, Validation Loss: 0.21819107,                    Best: 0.21770786, StopCount/Limit:   3/  3, Time:11.70780683
# Gen 8 Run End
# Run   8 Best: 0.08927468351274728, Mean: 0.10234012050119538, ID:1, config: [784   9   5   4   8   6   7   4   4   9  10], updatecount:   0, Generation RunTime: 434.49980903
# Gen 9 Run Start
# Next Gen: [784   7   5   4   6   5   6   7   6  10]
# ConfigID:   0, Epoch:   0, Training Loss: 0.22584569, Validation Loss: 0.16584964,                    Best: 0.16584964, StopCount/Limit:   0/  3, Time:9.60009289
# ConfigID:   0, Epoch:   1, Training Loss: 0.14754843, Validation Loss: 0.14143553,                    Best: 0.14143553, StopCount/Limit:   0/  3, Time:11.50509524
# ConfigID:   0, Epoch:   2, Training Loss: 0.13695530, Validation Loss: 0.13330267,                    Best: 0.13330267, StopCount/Limit:   0/  3, Time:14.89181399
# ConfigID:   0, Epoch:   3, Training Loss: 0.13128299, Validation Loss: 0.12694455,                    Best: 0.12694455, StopCount/Limit:   0/  3, Time:12.19314933
# ConfigID:   0, Epoch:   4, Training Loss: 0.12700991, Validation Loss: 0.12723107,                    Best: 0.12694455, StopCount/Limit:   1/  3, Time:10.34775305
# ConfigID:   0, Epoch:   5, Training Loss: 0.12459862, Validation Loss: 0.12163734,                    Best: 0.12163734, StopCount/Limit:   1/  3, Time:12.76796865
# ConfigID:   0, Epoch:   6, Training Loss: 0.12192092, Validation Loss: 0.11805750,                    Best: 0.11805750, StopCount/Limit:   1/  3, Time:12.20595884
# ConfigID:   0, Epoch:   7, Training Loss: 0.11997146, Validation Loss: 0.11806693,                    Best: 0.11805750, StopCount/Limit:   2/  3, Time:12.52215981
# ConfigID:   0, Epoch:   8, Training Loss: 0.11840827, Validation Loss: 0.11767539,                    Best: 0.11767539, StopCount/Limit:   2/  3, Time:11.88563514
# ConfigID:   0, Epoch:   9, Training Loss: 0.11738224, Validation Loss: 0.11608895,                    Best: 0.11608895, StopCount/Limit:   2/  3, Time:16.67925978
# ConfigID:   0, Epoch:  10, Training Loss: 0.11630747, Validation Loss: 0.12236578,                    Best: 0.11608895, StopCount/Limit:   3/  3, Time:23.68692303
# Next Gen: [784   9   5   4   8   6   7   4   4   9  10]
# ConfigID:   1, Epoch:   0, Training Loss: 0.28496207, Validation Loss: 0.25142026,                    Best: 0.25142026, StopCount/Limit:   0/  3, Time:14.87543201
# ConfigID:   1, Epoch:   1, Training Loss: 0.24117201, Validation Loss: 0.22804646,                    Best: 0.22804646, StopCount/Limit:   0/  3, Time:11.54032993
# ConfigID:   1, Epoch:   2, Training Loss: 0.21154713, Validation Loss: 0.20565392,                    Best: 0.20565392, StopCount/Limit:   0/  3, Time:11.34368110
# ConfigID:   1, Epoch:   3, Training Loss: 0.19579093, Validation Loss: 0.18711434,                    Best: 0.18711434, StopCount/Limit:   0/  3, Time:11.72004676
# ConfigID:   1, Epoch:   4, Training Loss: 0.18554123, Validation Loss: 0.18090327,                    Best: 0.18090327, StopCount/Limit:   0/  3, Time:12.02507067
# ConfigID:   1, Epoch:   5, Training Loss: 0.18006412, Validation Loss: 0.17793405,                    Best: 0.17793405, StopCount/Limit:   0/  3, Time:11.22400999
# ConfigID:   1, Epoch:   6, Training Loss: 0.17570507, Validation Loss: 0.17250752,                    Best: 0.17250752, StopCount/Limit:   0/  3, Time:12.69758797
# ConfigID:   1, Epoch:   7, Training Loss: 0.17053574, Validation Loss: 0.16758403,                    Best: 0.16758403, StopCount/Limit:   0/  3, Time:12.19424295
# ConfigID:   1, Epoch:   8, Training Loss: 0.16312257, Validation Loss: 0.15613206,                    Best: 0.15613206, StopCount/Limit:   0/  3, Time:11.72442389
# ConfigID:   1, Epoch:   9, Training Loss: 0.15653093, Validation Loss: 0.15393961,                    Best: 0.15393961, StopCount/Limit:   0/  3, Time:11.35197020
# ConfigID:   1, Epoch:  10, Training Loss: 0.15252019, Validation Loss: 0.14370803,                    Best: 0.14370803, StopCount/Limit:   0/  3, Time:10.72442794
# ConfigID:   1, Epoch:  11, Training Loss: 0.15125025, Validation Loss: 0.15496364,                    Best: 0.14370803, StopCount/Limit:   1/  3, Time:10.99645615
# ConfigID:   1, Epoch:  12, Training Loss: 0.15280732, Validation Loss: 0.14635629,                    Best: 0.14370803, StopCount/Limit:   2/  3, Time:11.46592617
# ConfigID:   1, Epoch:  13, Training Loss: 0.15040533, Validation Loss: 0.15405087,                    Best: 0.14370803, StopCount/Limit:   3/  3, Time:12.98014879
# Next Gen: [784   7   4   5   4   4  10   4   4   9  10]
# ConfigID:   2, Epoch:   0, Training Loss: 0.29080512, Validation Loss: 0.22120636,                    Best: 0.22120636, StopCount/Limit:   0/  3, Time:13.79815912
# ConfigID:   2, Epoch:   1, Training Loss: 0.20984309, Validation Loss: 0.19908228,                    Best: 0.19908228, StopCount/Limit:   0/  3, Time:11.30872607
# ConfigID:   2, Epoch:   2, Training Loss: 0.19527571, Validation Loss: 0.19204808,                    Best: 0.19204808, StopCount/Limit:   0/  3, Time:9.83656502
# ConfigID:   2, Epoch:   3, Training Loss: 0.19030450, Validation Loss: 0.18974244,                    Best: 0.18974244, StopCount/Limit:   0/  3, Time:10.91811609
# ConfigID:   2, Epoch:   4, Training Loss: 0.18637157, Validation Loss: 0.19209097,                    Best: 0.18974244, StopCount/Limit:   1/  3, Time:10.39057994
# ConfigID:   2, Epoch:   5, Training Loss: 0.18279648, Validation Loss: 0.18708346,                    Best: 0.18708346, StopCount/Limit:   1/  3, Time:11.02747703
# ConfigID:   2, Epoch:   6, Training Loss: 0.17717602, Validation Loss: 0.18845828,                    Best: 0.18708346, StopCount/Limit:   2/  3, Time:12.12342405
# ConfigID:   2, Epoch:   7, Training Loss: 0.17357551, Validation Loss: 0.18238365,                    Best: 0.18238365, StopCount/Limit:   2/  3, Time:10.06349897
# ConfigID:   2, Epoch:   8, Training Loss: 0.17161668, Validation Loss: 0.18413899,                    Best: 0.18238365, StopCount/Limit:   3/  3, Time:11.24217820
# Gen 9 Run End
# Run   9 Best: 0.08927468351274728, Mean: 0.10234012050119538, ID:1, config: [784   9   5   4   8   6   7   4   4   9  10], updatecount:   0, Generation RunTime: 415.92505288
# Run Completed : Best Score(loss): 0.08927468351274728 , Config: [784   9   5   4   8   6   7   4   4   9  10]
# /Users/heidi/opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/heidi/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
